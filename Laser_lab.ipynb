# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([np.sin(np.deg2rad(-36)),np.sin(np.deg2rad(-28)),np.sin(np.deg2rad(-23)),np.sin(np.deg2rad(-14)),np.sin(np.deg2rad(-7)),np.sin(np.deg2rad(0)),np.sin(np.deg2rad(7)),np.sin(np.deg2rad(14)),np.sin(np.deg2rad(21)),np.sin(np.deg2rad(29)),np.sin(np.deg2rad(34))])
array2 = np.array([np.sin(np.deg2rad(-50)),np.sin(np.deg2rad(-40)),np.sin(np.deg2rad(-30)),np.sin(np.deg2rad(-20)),np.sin(np.deg2rad(-10)),np.sin(np.deg2rad(0)),np.sin(np.deg2rad(10)),np.sin(np.deg2rad(20)),np.sin(np.deg2rad(30)),np.sin(np.deg2rad(40)),np.sin(np.deg2rad(50))])
errarray2 = np.array([0.014,0.0153,0.0160,0.0169,0.0173,0.0175,0.0173,0.0169,0.0160,0.0153,0.0140])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(array1,array2,errarray2,'Refraction Angle vs  Incident Angle','Refraction Angle(radians)','Incident Angle(radians)','')
# Out:
# Slope =  1.3480035416347669
# Error in slope =  0.01203001355274284
# Goodness of fit =  9.786541600191725
